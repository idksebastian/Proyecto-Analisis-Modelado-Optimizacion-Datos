# %%
#Revisar información general del dataset

#Importamos las librerias

import pandas as pd;
import matplotlib.pyplot as plt;
import seaborn as sns;


from google.colab import drive;

#Montamos el drive

drive.mount('gdrive')
ruta = '/content/gdrive/MyDrive/AnálisisEmpleo/Caracterización_del_Empleo_Público_20251206.csv'
df = pd.read_csv(ruta)
# Out:
# Drive already mounted at gdrive; to attempt to forcibly remount, call drive.mount("gdrive", force_remount=True).

# %%
# Revisar información general del dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 43 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   CÓDIGO SIGEP                          4134 non-null   int64
#  1   NOMBRE DE LA ENTIDAD                  4134 non-null   object
#  2   NIT                                   3632 non-null   float64
#  3   ORDEN                                 4134 non-null   object
#  4   SUBORDEN                              0 non-null      float64
#  5   REGIÓN PND                            0 non-null      float64
#  6   CÓDIGO DIVIPOLA DEPARTAMENTO          0 non-null      float64
#  7   DEPARTAMENTO                          0 non-null      float64
#  8   CÓDIGO DIVIPOLA MUNICIPIO             0 non-null      float64
#  9   MUNICIPIO                             0 non-null      float64
# ...

# %%
# 1. Manejo de valores nulos
# Verificar cuántos valores nulos hay por columna
df.isnull().sum()
# Out:
# CÓDIGO SIGEP                               0
# NOMBRE DE LA ENTIDAD                       0
# NIT                                      502
# ORDEN                                      0
# SUBORDEN                                4134
# REGIÓN PND                              4134
# CÓDIGO DIVIPOLA DEPARTAMENTO            4134
# DEPARTAMENTO                            4134
# CÓDIGO DIVIPOLA MUNICIPIO               4134
# MUNICIPIO                               4134
# CLASIFICACIÓN ORGÁNICA                     1
# SECTOR                                     0
# NIVEL                                      0
# TIPO DE VINCULACIÓN                        8
# NATURALEZA JURÍDICA                        0
# LONGITUD                                4134
# LATITUD                                 4134
# AÑO                                        0
# MES                                        0
# FUENTE                                     0
# GENERO: HOMBRE                             0
# ...

# %%
# Copia de seguridad del dataset original
df_prep = df.copy()

# %%
columnas_sin_info = [
    'SUBORDEN',
    'REGIÓN PND',
    'CÓDIGO DIVIPOLA DEPARTAMENTO',
    'DEPARTAMENTO',
    'CÓDIGO DIVIPOLA MUNICIPIO',
    'MUNICIPIO'
]

df_prep.drop(columns=columnas_sin_info, inplace=True, errors='ignore')

# %%
# Conversión de salario mensual promedio a formato numérico
df_prep["SALARIO MENSUAL PROMEDIO"] = (
    df_prep["SALARIO MENSUAL PROMEDIO"]
    .astype(str)
    .str.replace(",", "", regex=False)
    .astype(float)
)

# %%
df_prep["SALARIO MENSUAL PROMEDIO"].dtype
# Out:
# dtype('float64')

# %%
df_prep.isnull().sum()
# Out:
# CÓDIGO SIGEP                               0
# NOMBRE DE LA ENTIDAD                       0
# NIT                                      502
# ORDEN                                      0
# CLASIFICACIÓN ORGÁNICA                     1
# SECTOR                                     0
# NIVEL                                      0
# TIPO DE VINCULACIÓN                        8
# NATURALEZA JURÍDICA                        0
# LONGITUD                                4134
# LATITUD                                 4134
# AÑO                                        0
# MES                                        0
# FUENTE                                     0
# GENERO: HOMBRE                             0
# GENERO: MUJER                              0
# NIVEL EDUCATIVO: PRIMARIA                  0
# NIVEL EDUCATIVO: SECUNDARIA                0
# NIVEL EDUCATIVO: TÉCNICA-TECNOLÓGICA       0
# NIVEL EDUCATIVO: PROFESIONAL               0
# NIVEL EDUCATIVO: ESPECIALIZACIÓN           0
# ...

# %%
# Imputación de valores nulos con 0
df_prep = df_prep.fillna(0)

# %%
columnas_no_relevantes = [
    "NOMBRE DE LA ENTIDAD",
    "NIT",
    "CÓDIGO SIGEP"
]

df_prep = df_prep.drop(columns=columnas_no_relevantes, errors="ignore")

# %%
# Vista final de los datos preparados

df_prep.head()
# Out:
#          ORDEN CLASIFICACIÓN ORGÁNICA  \
# 0  TERRITORIAL              MUNICIPAL
# 1     NACIONAL              NO APLICA
# 2     NACIONAL              NO APLICA
# 3     NACIONAL              NO APLICA
# 4     NACIONAL              NO APLICA
#
#                                         SECTOR            NIVEL  \
# 0                                    NO APLICA  DESCENTRALIZADO
# 1                        RELACIONES EXTERIORES          CENTRAL
# 2                   HACIENDA Y CRÉDITO PÚBLICO          CENTRAL
# 3                                      DEFENSA          CENTRAL
# 4  AGROPECUARIO PESQUERO Y DE DESARROLLO RURAL          CENTRAL
#
#   TIPO DE VINCULACIÓN      NATURALEZA JURÍDICA  LONGITUD  LATITUD   AÑO  MES  \
# 0           ADSCRITAS  ESTABLECIMIENTO PÚBLICO       0.0      0.0  2025    3
# 1              CABEZA               MINISTERIO       0.0      0.0  2025    3
# 2              CABEZA               MINISTERIO       0.0      0.0  2025    3
# ...

# %%
df_prep.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4134 entries, 0 to 4133
# Data columns (total 34 columns):
#  #   Column                                Non-Null Count  Dtype
# ---  ------                                --------------  -----
#  0   ORDEN                                 4134 non-null   object
#  1   CLASIFICACIÓN ORGÁNICA                4134 non-null   object
#  2   SECTOR                                4134 non-null   object
#  3   NIVEL                                 4134 non-null   object
#  4   TIPO DE VINCULACIÓN                   4134 non-null   object
#  5   NATURALEZA JURÍDICA                   4134 non-null   object
#  6   LONGITUD                              4134 non-null   float64
#  7   LATITUD                               4134 non-null   float64
#  8   AÑO                                   4134 non-null   int64
#  9   MES                                   4134 non-null   int64
#  10  FUENTE                                4134 non-null   object
# ...
