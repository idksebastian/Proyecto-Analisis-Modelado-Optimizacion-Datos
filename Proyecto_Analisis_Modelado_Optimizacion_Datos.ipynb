# %% [markdown]
# <a href="https://colab.research.google.com/github/idksebastian/Proyecto-Analisis-Modelado-Optimizacion-Datos/blob/main/Proyecto_Analisis_Modelado_Optimizacion_Datos.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>
